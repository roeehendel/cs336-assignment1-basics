# %%
# %load_ext autoreload
# %autoreload 2

# %%
from configs.tinystories_config import config
from cs336_basics.training.lr_finding import run_lr_finding

cfg = config
lrs, losses = run_lr_finding(cfg, num_steps=400, start_lr=1e-8, stop_lr=1e-1, batch_size=2)
# Out:
# 100%|██████████| 400/400 [00:34<00:00, 11.48it/s]

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.plot(lrs, losses)
plt.xscale("log")
plt.ylim(np.min(losses), losses[0] * 1.05)
plt.show()
